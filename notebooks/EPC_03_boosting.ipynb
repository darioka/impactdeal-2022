# %%
#!git clone https://github.com/darioka/impactdeal-2022.git
#%cd impactdeal-2022
#!pip install -r requirements.txt
#!pip install .

# %% [markdown]
# # Boosting - EPC Rating
#
# In this notebook you fit a `HistGradientBoostingClassifier` on the EPC dataset.
#
# The first part of the pipeline, devoted to loading and cleaning the data, has already been written for you.
# The class `impactdeal.cleaning.Cleaner` apply the same steps we saw in previous notebooks. Take a look at the docstring if you are curious.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from impactdeal.config.column_names import TARGET, NUMERICAL, CATEGORICAL
from impactdeal.cleaning import Cleaner

df = pd.read_csv("../data/known_epc_ratings.csv.gz", parse_dates=["INSPECTION_DATE"], infer_datetime_format=True)
df = df.sort_values(["BUILDING_REFERENCE_NUMBER", "INSPECTION_DATE"]).drop_duplicates(subset="BUILDING_REFERENCE_NUMBER", keep="last")

y = df.pop(TARGET)
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, stratify=y, random_state=42)

cleaner = Cleaner()
X_train = cleaner.fit_transform(X_train)
X_test = cleaner.transform(X_test)
# Out:
# /home/darioka/anaconda3/envs/impactdeal/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cleaner.feature_names_in_
# Out:
# ['TOTAL_FLOOR_AREA',
#  'MULTI_GLAZE_PROPORTION',
#  'EXTENSION_COUNT',
#  'NUMBER_HABITABLE_ROOMS',
#  'NUMBER_HEATED_ROOMS',
#  'LOW_ENERGY_LIGHTING',
#  'NUMBER_OPEN_FIREPLACES',
#  'WIND_TURBINE_COUNT',
#  'FLOOR_HEIGHT',
#  'CITY',
#  'PROPERTY_TYPE',
#  'BUILT_FORM',
#  'CONSTRUCTION_AGE_BAND',
#  'ENERGY_TARIFF',
#  'MAINS_GAS_FLAG',
#  'FLOOR_LEVEL',
#  'FLAT_TOP_STOREY',
#  'MAIN_HEATING_CONTROLS',
#  'GLAZED_TYPE',
#  'GLAZED_AREA',
#  'MAIN_FUEL',
#  'SOLAR_WATER_HEATING_FLAG',
#  'MECHANICAL_VENTILATION']

# %%
X_train.head(5)
# Out:
#         TOTAL_FLOOR_AREA  MULTI_GLAZE_PROPORTION  EXTENSION_COUNT  \
# 548618             79.92                    78.0              0.0
# 501535            121.00                   100.0              1.0
# 813073             67.70                   100.0              0.0
# 519055            108.00                   100.0              0.0
# 353227             49.00                   100.0              0.0
#
#         NUMBER_HABITABLE_ROOMS  NUMBER_HEATED_ROOMS  LOW_ENERGY_LIGHTING  \
# 548618                     4.0                  4.0                 89.0
# 501535                     7.0                  7.0                  0.0
# 813073                     2.0                  1.0                  7.0
# 519055                     6.0                  6.0                 75.0
# 353227                     2.0                  2.0                100.0
#
#         NUMBER_OPEN_FIREPLACES  WIND_TURBINE_COUNT  FLOOR_HEIGHT        CITY  \
# 548618                     0.0                 0.0          2.62  Birmingham
# 501535                     1.0                 0.0           NaN  Birmingham
# 813073                     0.0                 0.0          2.43  Manchester
# 519055                     0.0                 0.0           NaN  Birmingham
# 353227                     0.0                 0.0           NaN  Birmingham
#
#         ... ENERGY_TARIFF MAINS_GAS_FLAG FLOOR_LEVEL FLAT_TOP_STOREY  \
# 548618  ...        Single              Y         NaN             NaN
# 501535  ...        Single              Y         NaN             NaN
# 813073  ...          dual              N         1st               Y
# 519055  ...        Single              Y         NaN             NaN
# 353227  ...        Single              N         1st               Y
#
#        MAIN_HEATING_CONTROLS                                    GLAZED_TYPE  \
# 548618                  2104           double glazing installed before 2002
# 501535                  2107  double glazing installed during or after 2002
# 813073                  2402           double glazing installed before 2002
# 519055                  2107           double glazing installed before 2002
# 353227                  2601           double glazing, unknown install date
#
#        GLAZED_AREA                                          MAIN_FUEL  \
# 548618      Normal  mains gas - this is for backwards compatibilit...
# 501535      Normal                          mains gas (not community)
# 813073      Normal  electricity - this is for backwards compatibil...
# 519055      Normal                          mains gas (not community)
# 353227      Normal                        electricity (not community)
#
#        SOLAR_WATER_HEATING_FLAG MECHANICAL_VENTILATION
# 548618                        N                natural
# 501535                        N                natural
# 813073                        N                natural
# 519055                      NaN                natural
# 353227                        N                natural
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Preprocessing
#
# It is time now to apply our usual preprocessing steps, namely:
#
# * missing value handling,
# * categorical encoding.
#
# But this time it's up to you. Should you replace missing or not? Which categorical encoder would you try? You are free to make choices, given the flexibility of `HistGradientBoostingClassifier`, but some choices may be better than others...

# %%
# Write your code here!

# %% [markdown]
# ## Training
#
# Finally, train and evaluate the model!

# %%
# Write your code here!
